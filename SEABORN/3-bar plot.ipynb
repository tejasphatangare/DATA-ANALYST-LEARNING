# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\tejas\Downloads\penguins.csv")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
sns.barplot(x='island',y='bill_length_mm',data=df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',)
plt.show()

# %%
ord=['Dream','Biscoe','Torgersen']
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',order=ord,hue_order=['FEMALE','MALE'],ci=0)
plt.show()
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_10452\3472694174.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',order=ord,hue_order=['FEMALE','MALE'],ci=0)

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df1=pd.read_csv(r"C:\Users\tejas\Downloads\penguins.csv").head(20)
sns.barplot(x='bill_depth_mm',y='bill_length_mm',data=df1,orient='horizontal')
plt.show()

# %%
ord=['Dream','Biscoe','Torgersen']
sns.set(style='dark')
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',order=ord,hue_order=['FEMALE','MALE'],
            color='Gold',saturation=70,errcolor='Blue')
plt.show()
