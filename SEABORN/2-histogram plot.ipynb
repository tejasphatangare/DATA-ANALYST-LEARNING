# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\tejas\Downloads\penguins.csv")

# %%
sns.histplot(df['flipper_length_mm'])
plt.show()

# %%
sns.displot(df['flipper_length_mm'],bins=[170,180,190,200,210,220,230,240])
plt.show()

# %%
sns.displot(df['flipper_length_mm'],bins=[170,180,190,200,210,220,230,240],kde=True,color='OrangeRed',rug=True)
plt.show()
