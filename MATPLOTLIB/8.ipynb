# %% [markdown]
# # SUB PLOT-

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[4,3,1,2]

plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.pie([1])

x1=[10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x1)


x2=[20,40,60,80]
y2=[2,4,6,8]
plt.subplot(2,2,4)
plt.bar(x2,y2)

plt.show()
